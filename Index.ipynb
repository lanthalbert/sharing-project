# %% [markdown]
# # My Watson Studio submission

# %% [markdown]
# __Albert Heinrich Lanthaler__
#
# I am a mechanical engineer and I work in the field of mechanical measurement

# %% [markdown]
# _I am interesten in data science because I work everyday with data and I would like to have more knowledge on data manipoulation and analysis of data._

# %% [markdown]
# ### My code is written in python and I print 'Hello World!'

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# * * *
#
# * Item 1
#
# 2. Item 2
